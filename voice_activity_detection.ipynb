# %% [markdown]
# <!-- This cell is automatically updated by tools/tutorial-cell-updater.py -->
# <!-- The contents are initialized from tutorials/notebook-header.md -->
#
# [<img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>](https://colab.research.google.com/github/speechbrain/speechbrain/blob/develop/docs/tutorials/tasks/voice-activity-detection.ipynb)
# to execute or view/download this notebook on
# [GitHub](https://github.com/speechbrain/speechbrain/tree/develop/docs/tutorials/tasks/voice-activity-detection.ipynb)

# %% [markdown]
# # Voice Activity Detection
#
# The goal of Voice Activity Detection (VAD) is to **detect** the **segments** containing **speech** within an audio recording.
#
# As shown in the following picture, the input of a VAD is an audio signal (or its corresponding features). The output could be a sequence that is "1" for the time frames containing speech and "0" for non-speech frames.

# %% [markdown]
# ![SpeechBrain-VAD.png](data:image/png;base64,...)

# %% [markdown]
# As an alternative, the VAD could provide in the output the **boundaries** where speech activity is detected. For instance:
#
#
#
# ```
# segment_001  0.00  2.57 NON_SPEECH
# segment_002  2.57  8.20 SPEECH
# segment_003  8.20  9.10 NON_SPEECH
# segment_004  9.10  10.93 SPEECH
# segment_005  10.93  12.00 NON_SPEECH
# segment_006  12.00  14.40 SPEECH
# segment_007  14.40  15.00 NON_SPEECH
# ```

# %% [markdown]
# ## What is VAD useful for?
#
# A VAD plays a crucial role in many speech processing pipelines. It is used when we would like to apply the processing algorithms to the **speech parts** of the audio recording only.
#
# For instance, it is often employed as a **pre-processing step** for speech recognition, speech enhancement, speaker diarization, and many others systems.

# %% [markdown]
# ## Why is challenging?

# %% [markdown]
# Discriminating speech from non-speech signals is very natural for humans. However, for a machine, this is much tricker. A good VAD should precisely detect speech activity even in **noisy** and **reverberant** conditions. The number of possible noise sources is huge in **real-life** conditions (e.g., music, telephone rings, alarms, etc.), making the problem challenging for a machine.
#
# Moreover, a good VAD should be able to process both short and very **long recordings** (e.g., meetings) and, ideally, shouldn't be too computationally expensive.

# %% [markdown]
# ## Pipeline description
#
# Robust Voice Activity Detection has been a very active research field for decades. Today, deep learning plays a crucial role in this problem as well.
#
# In this tutorial, we employ a neural network that provides speech/non-speech predictions for each input frame. The frame-level posterior probabilities are then post-processed to retrieve the final speech boundaries, as shown in the following figure:

# %% [markdown]
# ![SpeechBrain-VAD_CRDNN.png](data:image/png;base64,...)

# %% [markdown]
# More precisely, we here compute the standard FBANK features and we plug them into a CRDNN model (which combines convolutional, recurrent, and fully connected layers). The output is processed with a **sigmoid** to perform a **binary classification**. The network is trained with **binary cross-entropy**. The predictions will be close to one for speech and close to zero for non-speech frames.
#
# At inference time, the binary predictions are post-processed. For instance, we apply a **threshold** on them to identify the candidate speech regions. After that, we can apply other types of post-processing, such as merging segments that are close or remove segments that are too short. We will describe this in detail in the inference section.
#
# Right now, let's briefly discuss how we can train such a model with SpeechBrain.

# %% [markdown]
# ## Training
# SpeechBrain has a recipe for training a VAD with the [LibriParty Dataset](https://www.dropbox.com/s/ebo987wu3hie3zm/LibriParty.tar.gz?e=1&st=bjjs0754&dl=1). This is a dataset that we created for tasks such a VAD training. It contains several simulated acoustic scenes with speech and noisy sequences periodically active (alone or simultaneously).
#
# Beyond that, the training recipe creates **on-the-fly** several other **simulated acoustic scenes** using the Musan (that contains speech, noise, and music signals), CommonLanguage (that contains speech from 48 languages), and open-rir (that contains noise and impulse responses).
#
# The acoustic scene simulated on the fly explores different scenarios such as noise + speech, speech to noise transitions, noise to speech transitions, etc.
#
# Similarly to the other SpeechBrain recipes, one can train the model with the following commands:
#
#
#
# ```bash
# cd recipes/LibriParty/VAD
# python train.py hparams/train.yaml
# ```
#
# Please, follow the README file available within the recipe and make sure you have downloaded all the data before starting the training.
#
# Apart from the **massive use of speech augmentation/contamination**, the recipe has nothing special. Let's thus focus more on the inference part, which relies on some custom components.

# %% [markdown]
# ## Inference
#
# We can now focus on the inference part. The inference part is a bit more elaborated than usual because we designed it to work on very **long recordings** and to support several techniques for **post-processing** the network predictions.
#
# We will address all of the aforementioned aspects. But, let's first install speechbrain:

# %%
# %%capture
# Installing SpeechBrain via pip
BRANCH = 'develop'
# !python -m pip install git+https://github.com/speechbrain/speechbrain.git@$BRANCH

# %%
# %%capture
# !wget -O /content/example_vad_music.wav "https://www.dropbox.com/scl/fi/vvffxbkkuv79g0d4c7so3/example_vad_music.wav?rlkey=q5m5wc6y9fsfvt43x5yy8ohrf&dl=1"

# %% [markdown]
# Let's read a speech signal:

# %%
import torch
import torchaudio
import matplotlib.pyplot as plt
import soundfile as sf

audio_file = "example_vad_music.wav"

signal_np, fs = sf.read(audio_file)
signal = torch.tensor(signal_np, dtype=torch.float32).T  # shape: [channels, samples]
signal = signal.squeeze()

# signal, fs = torchaudio.load(audio_file)
# signal = signal.squeeze()
time = torch.linspace(0, signal.shape[0]/fs, steps=signal.shape[0])

plt.plot(time, signal)

from IPython.display import Audio
Audio(audio_file)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# We can now use the VAD trained at the previous step in the following way:

# %%
from speechbrain.inference.VAD import VAD

VAD = VAD.from_hparams(source="speechbrain/vad-crdnn-libriparty", savedir="pretrained_models/vad-crdnn-libriparty")
boundaries = VAD.get_speech_segments(audio_file)
VAD.save_boundaries(boundaries)
# Out:
# segment_001  0.00  0.23 NON_SPEECH
# segment_002  0.23  5.58 SPEECH
# segment_003  5.58  10.90 NON_SPEECH
# segment_004  10.90  16.63 SPEECH

# %% [markdown]
# As you can see, the two speech parts are detected correctly. The music part is correctly classified as a non-speech segment, while the part where both music and speech are active is classified as speech.

# %% [markdown]
# ## Inference Pipeline (Details)
#
# The pipeline for detecting the speech segments is the following:
#
# 1. Compute **posteriors probabilities** at the frame level.
# 2. Apply a **threshold** on the posterior probability.
# 3. Derive candidate speech segments on top of that.
# 4. Apply **energy VAD** within each candidate segment (optional).
# 5. **Merge segments** that are too close.
# 6. **Remove segments** that are too short.
# 7. **Double-check speech** segments (optional).
#
# To make debugging easier and the interface more **modular** and **transparent**, we allow users to access the output of these intermediate steps.
#
# In some cases, these steps are not all needed. Users are free to customize the pipeline and its hyperparameters to improve the performance on their data.
#
#
# Let's start with the posterior computation.
#
# ### 1- Posterior Computation
# The neural model provides outputs that should be close to zero for non-speech frames and close 1 one from speech frames.
#
# The time resolution depends on the **feature extraction** part and on the adopted neural **model**. In this case, we have a prediction every 10 ms (which is pretty standard for speech processing).
#
# To compute the posterior probabilities, you can use the following command:

# %%
prob_chunks = VAD.get_speech_prob_file(audio_file)
plt.plot(prob_chunks.squeeze())

# %% [markdown]
# As expected, we have high values for speech regions and low values for the music one.
#
# The `get_speech_prob_file function` is designed to process **long audio recordings**. It computes posterior probabilities on large chunks (e.g., 30 sec), that are read sequentially to avoid storing long signals in memory.
# Each large chunk is, in turn, split into smaller ones (e.g., 10 seconds)
# that are processed in parallel.
#
# You can tune the `large_chunk_size` and `small_chunk_size` based on your memory constraints. If you have enough memory, you can use it to store a larger chunk of the signal (e.g., 5 minutes). This can be done by increasing `large_chunk_size` and will make the VAD (slightly) faster.

# %% [markdown]
# ### 2- Apply a Threshold
#
# Now, we can detect the candidate speech segments by applying a threshold.
#
# To do it, you can use the following function:

# %%
prob_th = VAD.apply_threshold(prob_chunks, activation_th=0.5, deactivation_th=0.25).float()
plt.plot(prob_th.squeeze())

# %% [markdown]
# Instead of applying a single threshold (e.g., 0.5),  we allow users to set two different thresholds, one to decide when to start a speech segment (`activation_th`) and one to detect when to stop it (`deactivation_th`).
#
# According to our experience, it makes sense to set `activation_th` higher than than `deactivation_th` (e.g, `aactivation_th=0.5`, `deactivation_th=0.25`).
#
# Users, however, can play with these hyperparameters to make the VAD more or less selective.

# %% [markdown]
# ### 3- Get the Boundaries
# Now, we can derive the boundaries of the speech segments from the thresholded posteriors:

# %%
boundaries = VAD.get_boundaries(prob_th)
VAD.save_boundaries(boundaries, audio_file=audio_file)
# Out:
# segment_001  0.00  0.23 NON_SPEECH
# segment_002  0.23  5.58 SPEECH
# segment_003  5.58  10.90 NON_SPEECH
# segment_004  10.90  16.63 SPEECH
# segment_005  16.63  20.00 NON_SPEECH
# segment_006  20.00  20.43 SPEECH
# segment_007  20.43  20.45 NON_SPEECH

# %% [markdown]
# The `boundaries` tensors contain the beginning and end second of each speech segment.
# The method `save_boundaries` can be used to plot the boundaries in a human-readable format and/or to save them on a file (with the `save_path` argument).

# %% [markdown]
# ### 4- Energy-based VAD (optional)
#
# The trained neural VAD tends to detect large speech segments, where smaller speech segments that are close to each other are merged.
#
# If the users want more resolution, one possible approach is to apply an **energy-based VAD** within the detected speech segments. The energy-based VAD processes the speech segments with sliding windows that compute the energy within each chunk.  The energy profile is normalized such that we have  0.5 and +-0.5 of standard deviation. We then apply a threshold and split the speech original segment into smaller ones.
#
# This is done in the following way:

# %%
boundaries = VAD.energy_VAD(audio_file,boundaries, activation_th=0.8, deactivation_th=0.0)
VAD.save_boundaries(boundaries, audio_file=audio_file)
# Out:
# segment_001  0.00  1.66 NON_SPEECH
# segment_002  1.66  1.66 SPEECH
# segment_003  1.66  1.68 NON_SPEECH
# segment_004  1.68  1.68 SPEECH
# segment_005  1.68  1.70 NON_SPEECH
# segment_006  1.70  1.70 SPEECH
# segment_007  1.70  1.72 NON_SPEECH
# segment_008  1.72  1.72 SPEECH
# segment_009  1.72  1.74 NON_SPEECH
# segment_010  1.74  1.74 SPEECH
# segment_011  1.74  1.76 NON_SPEECH
# segment_012  1.76  1.76 SPEECH
# segment_013  1.76  1.78 NON_SPEECH
# segment_014  1.78  1.78 SPEECH
# segment_015  1.78  1.80 NON_SPEECH
# segment_016  1.80  1.80 SPEECH
# segment_017  1.80  1.82 NON_SPEECH
# segment_018  1.82  1.82 SPEECH
# segment_019  1.82  1.84 NON_SPEECH
# segment_020  1.84  1.84 SPEECH
# segment_021  1.84  1.86 NON_SPEECH
# segment_022  1.86  1.86 SPEECH
# segment_023  1.86  1.88 NON_SPEECH
# segment_024  1.88  1.88 SPEECH
# segment_025  1.88  1.90 NON_SPEECH
# segment_026  1.90  1.90 SPEECH
# segment_027  1.90  1.92 NON_SPEECH
# segment_028  1.92  1.92 SPEECH
# segment_029  1.92  1.94 NON_SPEECH
# segment_030  1.94  1.94 SPEECH
# segment_031  1.94  1.96 NON_SPEECH
# segment_032  1.96  1.96 SPEECH
# segment_033  1.96  1.98 NON_SPEECH
# segment_034  1.98  1.98 SPEECH
# segment_035  1.98  2.00 NON_SPEECH
# segment_036  2.00  2.00 SPEECH
# segment_037  2.00  2.02 NON_SPEECH
# segment_038  2.02  2.02 SPEECH
# segment_039  2.02  2.04 NON_SPEECH
# segment_040  2.04  2.04 SPEECH
# segment_041  2.04  2.06 NON_SPEECH
# segment_042  2.06  2.06 SPEECH
# segment_043  2.06  2.08 NON_SPEECH
# segment_044  2.08  2.08 SPEECH
# segment_045  2.08  2.10 NON_SPEECH
# segment_046  2.10  2.10 SPEECH
# segment_047  2.10  2.12 NON_SPEECH
# segment_048  2.12  2.12 SPEECH
# segment_049  2.12  2.14 NON_SPEECH
# segment_050  2.14  2.69 SPEECH
# segment_051  2.69  2.71 NON_SPEECH
# segment_052  2.71  2.71 SPEECH
# segment_053  2.71  2.73 NON_SPEECH
# segment_054  2.73  2.73 SPEECH
# segment_055  2.73  2.75 NON_SPEECH
# segment_056  2.75  2.75 SPEECH
# segment_057  2.75  2.77 NON_SPEECH
# segment_058  2.77  2.77 SPEECH
# segment_059  2.77  2.79 NON_SPEECH
# segment_060  2.79  2.79 SPEECH
# segment_061  2.79  2.81 NON_SPEECH
# segment_062  2.81  2.81 SPEECH
# segment_063  2.81  2.83 NON_SPEECH
# segment_064  2.83  2.83 SPEECH
# segment_065  2.83  2.85 NON_SPEECH
# segment_066  2.85  2.85 SPEECH
# segment_067  2.85  2.87 NON_SPEECH
# segment_068  2.87  2.87 SPEECH
# segment_069  2.87  2.89 NON_SPEECH
# segment_070  2.89  2.89 SPEECH
# segment_071  2.89  2.91 NON_SPEECH
# segment_072  2.91  2.91 SPEECH
# segment_073  2.91  2.93 NON_SPEECH
# segment_074  2.93  2.93 SPEECH
# segment_075  2.93  2.95 NON_SPEECH
# segment_076  2.95  2.95 SPEECH
# segment_077  2.95  2.97 NON_SPEECH
# segment_078  2.97  2.97 SPEECH
# segment_079  2.97  2.99 NON_SPEECH
# segment_080  2.99  2.99 SPEECH
# segment_081  2.99  3.01 NON_SPEECH
# segment_082  3.01  3.01 SPEECH
# segment_083  3.01  3.03 NON_SPEECH
# segment_084  3.03  3.03 SPEECH
# segment_085  3.03  3.05 NON_SPEECH
# segment_086  3.05  3.05 SPEECH
# segment_087  3.05  3.07 NON_SPEECH
# segment_088  3.07  3.07 SPEECH
# segment_089  3.07  3.09 NON_SPEECH
# segment_090  3.09  3.09 SPEECH
# segment_091  3.09  3.11 NON_SPEECH
# segment_092  3.11  3.11 SPEECH
# segment_093  3.11  3.13 NON_SPEECH
# segment_094  3.13  3.13 SPEECH
# segment_095  3.13  3.15 NON_SPEECH
# segment_096  3.15  3.15 SPEECH
# segment_097  3.15  3.17 NON_SPEECH
# segment_098  3.17  3.17 SPEECH
# segment_099  3.17  3.19 NON_SPEECH
# segment_100  3.19  3.19 SPEECH
# segment_101  3.19  3.21 NON_SPEECH
# segment_102  3.21  3.21 SPEECH
# segment_103  3.21  3.23 NON_SPEECH
# segment_104  3.23  3.23 SPEECH
# segment_105  3.23  3.25 NON_SPEECH
# segment_106  3.25  3.25 SPEECH
# segment_107  3.25  3.27 NON_SPEECH
# segment_108  3.27  3.27 SPEECH
# segment_109  3.27  3.29 NON_SPEECH
# segment_110  3.29  3.29 SPEECH
# segment_111  3.29  3.31 NON_SPEECH
# segment_112  3.31  3.31 SPEECH
# segment_113  3.31  3.33 NON_SPEECH
# segment_114  3.33  3.33 SPEECH
# segment_115  3.33  3.35 NON_SPEECH
# segment_116  3.35  3.35 SPEECH
# segment_117  3.35  3.37 NON_SPEECH
# segment_118  3.37  3.37 SPEECH
# segment_119  3.37  3.39 NON_SPEECH
# segment_120  3.39  3.39 SPEECH
# segment_121  3.39  3.41 NON_SPEECH
# segment_122  3.41  3.41 SPEECH
# segment_123  3.41  3.43 NON_SPEECH
# segment_124  3.43  3.43 SPEECH
# segment_125  3.43  3.45 NON_SPEECH
# segment_126  3.45  3.45 SPEECH
# segment_127  3.45  3.47 NON_SPEECH
# segment_128  3.47  3.47 SPEECH
# segment_129  3.47  3.49 NON_SPEECH
# segment_130  3.49  3.49 SPEECH
# segment_131  3.49  3.51 NON_SPEECH
# segment_132  3.51  3.51 SPEECH
# segment_133  3.51  3.53 NON_SPEECH
# segment_134  3.53  3.53 SPEECH
# segment_135  3.53  3.55 NON_SPEECH
# segment_136  3.55  3.55 SPEECH
# segment_137  3.55  3.57 NON_SPEECH
# segment_138  3.57  3.57 SPEECH
# segment_139  3.57  3.59 NON_SPEECH
# segment_140  3.59  3.59 SPEECH
# segment_141  3.59  3.61 NON_SPEECH
# segment_142  3.61  3.61 SPEECH
# segment_143  3.61  3.63 NON_SPEECH
# segment_144  3.63  3.63 SPEECH
# segment_145  3.63  3.65 NON_SPEECH
# segment_146  3.65  3.65 SPEECH
# segment_147  3.65  3.67 NON_SPEECH
# segment_148  3.67  3.67 SPEECH
# segment_149  3.67  3.69 NON_SPEECH
# segment_150  3.69  3.69 SPEECH
# segment_151  3.69  3.71 NON_SPEECH
# segment_152  3.71  3.71 SPEECH
# segment_153  3.71  3.73 NON_SPEECH
# segment_154  3.73  3.73 SPEECH
# segment_155  3.73  3.75 NON_SPEECH
# segment_156  3.75  3.75 SPEECH
# segment_157  3.75  3.77 NON_SPEECH
# segment_158  3.77  3.77 SPEECH
# segment_159  3.77  3.79 NON_SPEECH
# segment_160  3.79  3.79 SPEECH
# segment_161  3.79  3.81 NON_SPEECH
# segment_162  3.81  3.81 SPEECH
# segment_163  3.81  3.83 NON_SPEECH
# segment_164  3.83  3.83 SPEECH
# segment_165  3.83  3.85 NON_SPEECH
# segment_166  3.85  3.85 SPEECH
# segment_167  3.85  3.87 NON_SPEECH
# segment_168  3.87  3.87 SPEECH
# segment_169  3.87  3.89 NON_SPEECH
# segment_170  3.89  3.89 SPEECH
# segment_171  3.89  3.91 NON_SPEECH
# segment_172  3.91  3.91 SPEECH
# segment_173  3.91  3.93 NON_SPEECH
# segment_174  3.93  3.93 SPEECH
# segment_175  3.93  3.95 NON_SPEECH
# segment_176  3.95  3.95 SPEECH
# segment_177  3.95  3.97 NON_SPEECH
# segment_178  3.97  3.97 SPEECH
# segment_179  3.97  3.99 NON_SPEECH
# segment_180  3.99  3.99 SPEECH
# segment_181  3.99  4.01 NON_SPEECH
# segment_182  4.01  4.01 SPEECH
# segment_183  4.01  4.03 NON_SPEECH
# segment_184  4.03  4.03 SPEECH
# segment_185  4.03  4.27 NON_SPEECH
# segment_186  4.27  4.27 SPEECH
# segment_187  4.27  4.29 NON_SPEECH
# segment_188  4.29  4.29 SPEECH
# segment_189  4.29  4.31 NON_SPEECH
# segment_190  4.31  4.31 SPEECH
# segment_191  4.31  4.33 NON_SPEECH
# segment_192  4.33  4.33 SPEECH
# segment_193  4.33  4.35 NON_SPEECH
# segment_194  4.35  4.35 SPEECH
# segment_195  4.35  4.37 NON_SPEECH
# segment_196  4.37  4.37 SPEECH
# segment_197  4.37  4.39 NON_SPEECH
# segment_198  4.39  4.39 SPEECH
# segment_199  4.39  4.41 NON_SPEECH
# segment_200  4.41  4.41 SPEECH
# segment_201  4.41  4.43 NON_SPEECH
# segment_202  4.43  4.43 SPEECH
# segment_203  4.43  4.45 NON_SPEECH
# segment_204  4.45  4.45 SPEECH
# segment_205  4.45  4.47 NON_SPEECH
# segment_206  4.47  4.47 SPEECH
# segment_207  4.47  4.49 NON_SPEECH
# segment_208  4.49  4.49 SPEECH
# segment_209  4.49  4.51 NON_SPEECH
# segment_210  4.51  4.51 SPEECH
# segment_211  4.51  4.53 NON_SPEECH
# segment_212  4.53  4.53 SPEECH
# segment_213  4.53  4.55 NON_SPEECH
# segment_214  4.55  4.55 SPEECH
# segment_215  4.55  4.57 NON_SPEECH
# segment_216  4.57  4.57 SPEECH
# segment_217  4.57  4.59 NON_SPEECH
# segment_218  4.59  4.59 SPEECH
# segment_219  4.59  4.61 NON_SPEECH
# segment_220  4.61  4.61 SPEECH
# segment_221  4.61  4.63 NON_SPEECH
# segment_222  4.63  4.63 SPEECH
# segment_223  4.63  4.65 NON_SPEECH
# segment_224  4.65  4.65 SPEECH
# segment_225  4.65  4.67 NON_SPEECH
# segment_226  4.67  4.67 SPEECH
# segment_227  4.67  4.69 NON_SPEECH
# segment_228  4.69  4.69 SPEECH
# segment_229  4.69  4.71 NON_SPEECH
# segment_230  4.71  4.71 SPEECH
# segment_231  4.71  4.73 NON_SPEECH
# segment_232  4.73  4.73 SPEECH
# segment_233  4.73  4.75 NON_SPEECH
# segment_234  4.75  4.75 SPEECH
# segment_235  4.75  4.77 NON_SPEECH
# segment_236  4.77  4.77 SPEECH
# segment_237  4.77  4.79 NON_SPEECH
# segment_238  4.79  4.79 SPEECH
# segment_239  4.79  4.81 NON_SPEECH
# segment_240  4.81  4.81 SPEECH
# segment_241  4.81  4.83 NON_SPEECH
# segment_242  4.83  4.83 SPEECH
# segment_243  4.83  4.85 NON_SPEECH
# segment_244  4.85  4.85 SPEECH
# segment_245  4.85  4.87 NON_SPEECH
# segment_246  4.87  4.87 SPEECH
# segment_247  4.87  4.89 NON_SPEECH
# segment_248  4.89  4.89 SPEECH
# segment_249  4.89  4.91 NON_SPEECH
# segment_250  4.91  4.91 SPEECH
# segment_251  4.91  4.93 NON_SPEECH
# segment_252  4.93  4.93 SPEECH
# segment_253  4.93  4.95 NON_SPEECH
# segment_254  4.95  4.95 SPEECH
# segment_255  4.95  4.97 NON_SPEECH
# segment_256  4.97  4.97 SPEECH
# segment_257  4.97  4.99 NON_SPEECH
# segment_258  4.99  4.99 SPEECH
# segment_259  4.99  5.01 NON_SPEECH
# segment_260  5.01  5.01 SPEECH
# segment_261  5.01  5.03 NON_SPEECH
# segment_262  5.03  5.03 SPEECH
# segment_263  5.03  5.05 NON_SPEECH
# segment_264  5.05  5.05 SPEECH
# segment_265  5.05  5.07 NON_SPEECH
# segment_266  5.07  5.07 SPEECH
# segment_267  5.07  5.09 NON_SPEECH
# segment_268  5.09  5.09 SPEECH
# segment_269  5.09  5.11 NON_SPEECH
# segment_270  5.11  5.11 SPEECH
# segment_271  5.11  5.13 NON_SPEECH
# segment_272  5.13  5.13 SPEECH
# segment_273  5.13  5.15 NON_SPEECH
# segment_274  5.15  5.15 SPEECH
# segment_275  5.15  5.17 NON_SPEECH
# segment_276  5.17  5.17 SPEECH
# segment_277  5.17  5.19 NON_SPEECH
# segment_278  5.19  5.19 SPEECH
# segment_279  5.19  5.21 NON_SPEECH
# segment_280  5.21  5.21 SPEECH
# segment_281  5.21  5.23 NON_SPEECH
# segment_282  5.23  5.23 SPEECH
# segment_283  5.23  5.25 NON_SPEECH
# segment_284  5.25  5.25 SPEECH
# segment_285  5.25  5.27 NON_SPEECH
# segment_286  5.27  5.57 SPEECH
# segment_287  5.57  11.37 NON_SPEECH
# segment_288  11.37  11.37 SPEECH
# segment_289  11.37  11.39 NON_SPEECH
# segment_290  11.39  11.39 SPEECH
# segment_291  11.39  11.41 NON_SPEECH
# segment_292  11.41  11.41 SPEECH
# segment_293  11.41  11.43 NON_SPEECH
# segment_294  11.43  11.43 SPEECH
# segment_295  11.43  11.45 NON_SPEECH
# segment_296  11.45  11.45 SPEECH
# segment_297  11.45  11.47 NON_SPEECH
# segment_298  11.47  11.47 SPEECH
# segment_299  11.47  11.49 NON_SPEECH
# segment_300  11.49  11.49 SPEECH
# segment_301  11.49  11.51 NON_SPEECH
# segment_302  11.51  11.51 SPEECH
# segment_303  11.51  11.53 NON_SPEECH
# segment_304  11.53  11.53 SPEECH
# segment_305  11.53  11.55 NON_SPEECH
# segment_306  11.55  11.55 SPEECH
# segment_307  11.55  11.57 NON_SPEECH
# segment_308  11.57  11.57 SPEECH
# segment_309  11.57  11.59 NON_SPEECH
# segment_310  11.59  11.59 SPEECH
# segment_311  11.59  11.61 NON_SPEECH
# segment_312  11.61  11.61 SPEECH
# segment_313  11.61  11.63 NON_SPEECH
# segment_314  11.63  11.63 SPEECH
# segment_315  11.63  11.65 NON_SPEECH
# segment_316  11.65  11.65 SPEECH
# segment_317  11.65  11.67 NON_SPEECH
# segment_318  11.67  11.67 SPEECH
# segment_319  11.67  11.69 NON_SPEECH
# segment_320  11.69  11.69 SPEECH
# segment_321  11.69  11.71 NON_SPEECH
# segment_322  11.71  11.71 SPEECH
# segment_323  11.71  11.73 NON_SPEECH
# segment_324  11.73  11.73 SPEECH
# segment_325  11.73  11.75 NON_SPEECH
# segment_326  11.75  11.75 SPEECH
# segment_327  11.75  11.77 NON_SPEECH
# segment_328  11.77  11.77 SPEECH
# segment_329  11.77  11.79 NON_SPEECH
# segment_330  11.79  11.79 SPEECH
# segment_331  11.79  11.81 NON_SPEECH
# segment_332  11.81  11.81 SPEECH
# segment_333  11.81  11.83 NON_SPEECH
# segment_334  11.83  11.83 SPEECH
# segment_335  11.83  11.85 NON_SPEECH
# segment_336  11.85  11.85 SPEECH
# segment_337  11.85  11.87 NON_SPEECH
# segment_338  11.87  11.87 SPEECH
# segment_339  11.87  11.89 NON_SPEECH
# segment_340  11.89  11.89 SPEECH
# segment_341  11.89  11.91 NON_SPEECH
# segment_342  11.91  11.91 SPEECH
# segment_343  11.91  11.93 NON_SPEECH
# segment_344  11.93  11.93 SPEECH
# segment_345  11.93  11.95 NON_SPEECH
# segment_346  11.95  12.62 SPEECH
# segment_347  12.62  12.64 NON_SPEECH
# segment_348  12.64  12.64 SPEECH
# segment_349  12.64  12.66 NON_SPEECH
# segment_350  12.66  12.66 SPEECH
# segment_351  12.66  12.68 NON_SPEECH
# segment_352  12.68  12.68 SPEECH
# segment_353  12.68  12.70 NON_SPEECH
# segment_354  12.70  12.70 SPEECH
# segment_355  12.70  12.72 NON_SPEECH
# segment_356  12.72  12.72 SPEECH
# segment_357  12.72  12.74 NON_SPEECH
# segment_358  12.74  12.74 SPEECH
# segment_359  12.74  12.76 NON_SPEECH
# segment_360  12.76  12.76 SPEECH
# segment_361  12.76  12.78 NON_SPEECH
# segment_362  12.78  12.78 SPEECH
# segment_363  12.78  12.80 NON_SPEECH
# segment_364  12.80  12.80 SPEECH
# segment_365  12.80  12.82 NON_SPEECH
# segment_366  12.82  12.82 SPEECH
# segment_367  12.82  12.84 NON_SPEECH
# segment_368  12.84  12.84 SPEECH
# segment_369  12.84  12.86 NON_SPEECH
# segment_370  12.86  12.86 SPEECH
# segment_371  12.86  12.88 NON_SPEECH
# segment_372  12.88  12.88 SPEECH
# segment_373  12.88  12.90 NON_SPEECH
# segment_374  12.90  12.90 SPEECH
# segment_375  12.90  12.92 NON_SPEECH
# segment_376  12.92  12.92 SPEECH
# segment_377  12.92  12.94 NON_SPEECH
# segment_378  12.94  12.94 SPEECH
# segment_379  12.94  12.96 NON_SPEECH
# segment_380  12.96  12.96 SPEECH
# segment_381  12.96  12.98 NON_SPEECH
# segment_382  12.98  12.98 SPEECH
# segment_383  12.98  13.00 NON_SPEECH
# segment_384  13.00  13.00 SPEECH
# segment_385  13.00  13.02 NON_SPEECH
# segment_386  13.02  13.02 SPEECH
# segment_387  13.02  13.04 NON_SPEECH
# segment_388  13.04  13.04 SPEECH
# segment_389  13.04  13.06 NON_SPEECH
# segment_390  13.06  13.06 SPEECH
# segment_391  13.06  13.08 NON_SPEECH
# segment_392  13.08  13.08 SPEECH
# segment_393  13.08  13.10 NON_SPEECH
# segment_394  13.10  13.10 SPEECH
# segment_395  13.10  13.12 NON_SPEECH
# segment_396  13.12  13.12 SPEECH
# segment_397  13.12  13.26 NON_SPEECH
# segment_398  13.26  13.26 SPEECH
# segment_399  13.26  13.28 NON_SPEECH
# segment_400  13.28  13.28 SPEECH
# segment_401  13.28  13.30 NON_SPEECH
# segment_402  13.30  13.30 SPEECH
# segment_403  13.30  13.32 NON_SPEECH
# segment_404  13.32  13.32 SPEECH
# segment_405  13.32  13.34 NON_SPEECH
# segment_406  13.34  13.34 SPEECH
# segment_407  13.34  13.36 NON_SPEECH
# segment_408  13.36  13.36 SPEECH
# segment_409  13.36  13.38 NON_SPEECH
# segment_410  13.38  13.38 SPEECH
# segment_411  13.38  13.40 NON_SPEECH
# segment_412  13.40  13.40 SPEECH
# segment_413  13.40  13.42 NON_SPEECH
# segment_414  13.42  13.42 SPEECH
# segment_415  13.42  13.44 NON_SPEECH
# segment_416  13.44  13.44 SPEECH
# segment_417  13.44  13.46 NON_SPEECH
# segment_418  13.46  13.46 SPEECH
# segment_419  13.46  13.48 NON_SPEECH
# segment_420  13.48  13.48 SPEECH
# segment_421  13.48  13.50 NON_SPEECH
# segment_422  13.50  13.50 SPEECH
# segment_423  13.50  13.52 NON_SPEECH
# segment_424  13.52  13.52 SPEECH
# segment_425  13.52  13.54 NON_SPEECH
# segment_426  13.54  13.54 SPEECH
# segment_427  13.54  13.56 NON_SPEECH
# segment_428  13.56  13.56 SPEECH
# segment_429  13.56  13.58 NON_SPEECH
# segment_430  13.58  13.58 SPEECH
# segment_431  13.58  13.60 NON_SPEECH
# segment_432  13.60  13.60 SPEECH
# segment_433  13.60  13.62 NON_SPEECH
# segment_434  13.62  13.62 SPEECH
# segment_435  13.62  13.64 NON_SPEECH
# segment_436  13.64  13.64 SPEECH
# segment_437  13.64  13.66 NON_SPEECH
# segment_438  13.66  13.66 SPEECH
# segment_439  13.66  13.68 NON_SPEECH
# segment_440  13.68  13.68 SPEECH
# segment_441  13.68  13.70 NON_SPEECH
# segment_442  13.70  13.70 SPEECH
# segment_443  13.70  13.72 NON_SPEECH
# segment_444  13.72  13.72 SPEECH
# segment_445  13.72  13.74 NON_SPEECH
# segment_446  13.74  13.74 SPEECH
# segment_447  13.74  13.76 NON_SPEECH
# segment_448  13.76  13.76 SPEECH
# segment_449  13.76  13.78 NON_SPEECH
# segment_450  13.78  13.78 SPEECH
# segment_451  13.78  13.80 NON_SPEECH
# segment_452  13.80  13.80 SPEECH
# segment_453  13.80  13.82 NON_SPEECH
# segment_454  13.82  13.82 SPEECH
# segment_455  13.82  13.84 NON_SPEECH
# segment_456  13.84  13.84 SPEECH
# segment_457  13.84  13.86 NON_SPEECH
# segment_458  13.86  13.86 SPEECH
# segment_459  13.86  13.88 NON_SPEECH
# segment_460  13.88  13.88 SPEECH
# segment_461  13.88  13.90 NON_SPEECH
# segment_462  13.90  13.90 SPEECH
# segment_463  13.90  13.92 NON_SPEECH
# segment_464  13.92  13.92 SPEECH
# segment_465  13.92  13.94 NON_SPEECH
# segment_466  13.94  13.94 SPEECH
# segment_467  13.94  13.96 NON_SPEECH
# segment_468  13.96  13.96 SPEECH
# segment_469  13.96  13.98 NON_SPEECH
# segment_470  13.98  13.98 SPEECH
# segment_471  13.98  14.00 NON_SPEECH
# segment_472  14.00  14.00 SPEECH
# segment_473  14.00  14.02 NON_SPEECH
# segment_474  14.02  14.02 SPEECH
# segment_475  14.02  14.04 NON_SPEECH
# segment_476  14.04  14.04 SPEECH
# segment_477  14.04  14.06 NON_SPEECH
# segment_478  14.06  14.06 SPEECH
# segment_479  14.06  14.08 NON_SPEECH
# segment_480  14.08  14.08 SPEECH
# segment_481  14.08  14.10 NON_SPEECH
# segment_482  14.10  14.10 SPEECH
# segment_483  14.10  14.12 NON_SPEECH
# segment_484  14.12  14.12 SPEECH
# segment_485  14.12  14.14 NON_SPEECH
# segment_486  14.14  14.14 SPEECH
# segment_487  14.14  14.16 NON_SPEECH
# segment_488  14.16  14.16 SPEECH
# segment_489  14.16  14.18 NON_SPEECH
# segment_490  14.18  14.18 SPEECH
# segment_491  14.18  14.20 NON_SPEECH
# segment_492  14.20  14.20 SPEECH
# segment_493  14.20  14.22 NON_SPEECH
# segment_494  14.22  14.22 SPEECH
# segment_495  14.22  14.24 NON_SPEECH
# segment_496  14.24  14.24 SPEECH
# segment_497  14.24  14.26 NON_SPEECH
# segment_498  14.26  14.26 SPEECH
# segment_499  14.26  14.28 NON_SPEECH
# segment_500  14.28  14.28 SPEECH
# segment_501  14.28  14.99 NON_SPEECH
# segment_502  14.99  14.99 SPEECH
# segment_503  14.99  15.01 NON_SPEECH
# segment_504  15.01  15.01 SPEECH
# segment_505  15.01  15.03 NON_SPEECH
# segment_506  15.03  15.03 SPEECH
# segment_507  15.03  15.05 NON_SPEECH
# segment_508  15.05  15.05 SPEECH
# segment_509  15.05  15.07 NON_SPEECH
# segment_510  15.07  15.07 SPEECH
# segment_511  15.07  15.09 NON_SPEECH
# segment_512  15.09  15.09 SPEECH
# segment_513  15.09  15.11 NON_SPEECH
# segment_514  15.11  15.11 SPEECH
# segment_515  15.11  15.13 NON_SPEECH
# segment_516  15.13  15.13 SPEECH
# segment_517  15.13  15.15 NON_SPEECH
# segment_518  15.15  15.15 SPEECH
# segment_519  15.15  15.17 NON_SPEECH
# segment_520  15.17  15.17 SPEECH
# segment_521  15.17  15.19 NON_SPEECH
# segment_522  15.19  15.19 SPEECH
# segment_523  15.19  15.21 NON_SPEECH
# segment_524  15.21  15.21 SPEECH
# segment_525  15.21  15.23 NON_SPEECH
# segment_526  15.23  15.23 SPEECH
# segment_527  15.23  15.25 NON_SPEECH
# segment_528  15.25  15.25 SPEECH
# segment_529  15.25  15.27 NON_SPEECH
# segment_530  15.27  15.27 SPEECH
# segment_531  15.27  15.29 NON_SPEECH
# segment_532  15.29  15.29 SPEECH
# segment_533  15.29  15.31 NON_SPEECH
# segment_534  15.31  15.31 SPEECH
# segment_535  15.31  15.33 NON_SPEECH
# segment_536  15.33  15.33 SPEECH
# segment_537  15.33  15.35 NON_SPEECH
# segment_538  15.35  15.35 SPEECH
# segment_539  15.35  15.37 NON_SPEECH
# segment_540  15.37  15.37 SPEECH
# segment_541  15.37  15.39 NON_SPEECH
# segment_542  15.39  15.39 SPEECH
# segment_543  15.39  15.41 NON_SPEECH
# segment_544  15.41  15.41 SPEECH
# segment_545  15.41  15.43 NON_SPEECH
# segment_546  15.43  15.43 SPEECH
# segment_547  15.43  15.45 NON_SPEECH
# segment_548  15.45  15.45 SPEECH
# segment_549  15.45  15.47 NON_SPEECH
# segment_550  15.47  15.47 SPEECH
# segment_551  15.47  15.49 NON_SPEECH
# segment_552  15.49  15.49 SPEECH
# segment_553  15.49  15.51 NON_SPEECH
# segment_554  15.51  15.51 SPEECH
# segment_555  15.51  15.53 NON_SPEECH
# segment_556  15.53  15.53 SPEECH
# segment_557  15.53  15.55 NON_SPEECH
# segment_558  15.55  15.55 SPEECH
# segment_559  15.55  15.57 NON_SPEECH
# segment_560  15.57  15.57 SPEECH
# segment_561  15.57  15.59 NON_SPEECH
# segment_562  15.59  15.59 SPEECH
# segment_563  15.59  15.61 NON_SPEECH
# segment_564  15.61  15.61 SPEECH
# segment_565  15.61  15.63 NON_SPEECH
# segment_566  15.63  15.63 SPEECH
# segment_567  15.63  15.65 NON_SPEECH
# segment_568  15.65  15.65 SPEECH
# segment_569  15.65  15.67 NON_SPEECH
# segment_570  15.67  15.67 SPEECH
# segment_571  15.67  15.79 NON_SPEECH
# segment_572  15.79  15.79 SPEECH
# segment_573  15.79  15.81 NON_SPEECH
# segment_574  15.81  15.81 SPEECH
# segment_575  15.81  15.83 NON_SPEECH
# segment_576  15.83  15.83 SPEECH
# segment_577  15.83  15.85 NON_SPEECH
# segment_578  15.85  15.85 SPEECH
# segment_579  15.85  15.87 NON_SPEECH
# segment_580  15.87  15.87 SPEECH
# segment_581  15.87  15.89 NON_SPEECH
# segment_582  15.89  15.89 SPEECH
# segment_583  15.89  15.91 NON_SPEECH
# segment_584  15.91  15.91 SPEECH
# segment_585  15.91  15.93 NON_SPEECH
# segment_586  15.93  15.93 SPEECH
# segment_587  15.93  15.95 NON_SPEECH
# segment_588  15.95  15.95 SPEECH
# segment_589  15.95  15.97 NON_SPEECH
# segment_590  15.97  15.97 SPEECH
# segment_591  15.97  15.99 NON_SPEECH
# segment_592  15.99  15.99 SPEECH
# segment_593  15.99  16.01 NON_SPEECH
# segment_594  16.01  16.01 SPEECH
# segment_595  16.01  16.03 NON_SPEECH
# segment_596  16.03  16.03 SPEECH
# segment_597  16.03  16.05 NON_SPEECH
# segment_598  16.05  16.05 SPEECH
# segment_599  16.05  16.07 NON_SPEECH
# segment_600  16.07  16.29 SPEECH
# segment_601  16.29  16.31 NON_SPEECH
# segment_602  16.31  16.31 SPEECH
# segment_603  16.31  16.33 NON_SPEECH
# segment_604  16.33  16.33 SPEECH
# segment_605  16.33  16.35 NON_SPEECH
# segment_606  16.35  16.35 SPEECH
# segment_607  16.35  16.37 NON_SPEECH
# segment_608  16.37  16.37 SPEECH
# segment_609  16.37  16.39 NON_SPEECH
# segment_610  16.39  16.39 SPEECH
# segment_611  16.39  16.41 NON_SPEECH
# segment_612  16.41  16.41 SPEECH
# segment_613  16.41  16.43 NON_SPEECH
# segment_614  16.43  16.62 SPEECH
# segment_615  16.62  20.02 NON_SPEECH
# segment_616  20.02  20.02 SPEECH
# segment_617  20.02  20.04 NON_SPEECH
# segment_618  20.04  20.04 SPEECH
# segment_619  20.04  20.06 NON_SPEECH
# segment_620  20.06  20.06 SPEECH
# segment_621  20.06  20.08 NON_SPEECH
# segment_622  20.08  20.08 SPEECH
# segment_623  20.08  20.10 NON_SPEECH
# segment_624  20.10  20.10 SPEECH
# segment_625  20.10  20.18 NON_SPEECH
# segment_626  20.18  20.18 SPEECH
# segment_627  20.18  20.22 NON_SPEECH
# segment_628  20.22  20.22 SPEECH
# segment_629  20.22  20.29 NON_SPEECH
# segment_630  20.29  20.29 SPEECH
# segment_631  20.29  20.31 NON_SPEECH
# segment_632  20.31  20.31 SPEECH
# segment_633  20.31  20.33 NON_SPEECH
# segment_634  20.33  20.33 SPEECH
# segment_635  20.33  20.35 NON_SPEECH
# segment_636  20.35  20.35 SPEECH
# segment_637  20.35  20.37 NON_SPEECH
# segment_638  20.37  20.37 SPEECH
# segment_639  20.37  20.42 NON_SPEECH
# segment_640  20.42  20.42 SPEECH
# segment_641  20.42  20.45 NON_SPEECH

# %% [markdown]
# Users can have a more or less selective VAD by playing with `activation_th` and `deactivation_th`.
#
# Differently from the neural VAD, the energy VAD tends to oversegment the input. We improve that by post-processing the boundaries, as will be shown below.

# %% [markdown]
# ### 5- Merge close segments
# The users might need to select the desired resolution for the VAD (the optimal level of granularity might depend on the task).
#
# For instance, it could make sense to **merge segments** that are too close to each other.
#
# This is done with the following method:

# %%
# 5- Merge segments that are too close
boundaries = VAD.merge_close_segments(boundaries, close_th=0.250)
VAD.save_boundaries(boundaries, audio_file=audio_file)
# Out:
# segment_001  0.00  1.66 NON_SPEECH
# segment_002  1.66  5.57 SPEECH
# segment_003  5.57  11.37 NON_SPEECH
# segment_004  11.37  14.28 SPEECH
# segment_005  14.28  14.99 NON_SPEECH
# segment_006  14.99  16.62 SPEECH
# segment_007  16.62  20.02 NON_SPEECH
# segment_008  20.02  20.42 SPEECH
# segment_009  20.42  20.45 NON_SPEECH

# %% [markdown]
# In this case, we merged segments that are closer than 250 ms. Users can play with `close_th` and tune it according to their needs.

# %% [markdown]
# ### 6- Remove short segments
# It could also make sense to remove short isolated segments that might be misclassified as speech:

# %%
# 6- Remove segments that are too short
boundaries = VAD.remove_short_segments(boundaries, len_th=0.250)
VAD.save_boundaries(boundaries, audio_file=audio_file)
# Out:
# segment_001  0.00  1.66 NON_SPEECH
# segment_002  1.66  5.57 SPEECH
# segment_003  5.57  11.37 NON_SPEECH
# segment_004  11.37  14.28 SPEECH
# segment_005  14.28  14.99 NON_SPEECH
# segment_006  14.99  16.62 SPEECH
# segment_007  16.62  20.02 NON_SPEECH
# segment_008  20.02  20.42 SPEECH
# segment_009  20.42  20.45 NON_SPEECH

# %% [markdown]
# In this case, we remove segments that are shorter than 250 ms. Note that we first merged segments that are close and only after we removed the short ones. This helps to remove short "isolated"  segments only.

# %% [markdown]
# ### 7- Double check speech segments (optional)
#
# At this point, we can take the post-processed speech segments and double-check if they really contain speech. This is done in this way:

# %%
# 7- Double-check speech segments (optional).
boundaries = VAD.double_check_speech_segments(boundaries, audio_file,  speech_th=0.5)
VAD.save_boundaries(boundaries, audio_file=audio_file)
# Out:
# segment_001  0.00  1.66 NON_SPEECH
# segment_002  1.66  5.57 SPEECH
# segment_003  5.57  11.37 NON_SPEECH
# segment_004  11.37  14.28 SPEECH
# segment_005  14.28  14.99 NON_SPEECH
# segment_006  14.99  16.62 SPEECH
# segment_007  16.62  20.45 NON_SPEECH

# %% [markdown]
# The method uses one more time the neural VAD on the detected speech segments. If the **average posterior probability within the segment** is larger than `speech_th` (in this case, `speech_th=0.5`), the speech segment is confirmed. Otherwise,  it is removed.

# %% [markdown]
# ## Visualization
#
# We also implemented some utilities to help users visualizing the output of the VAD:

# %%
upsampled_boundaries = VAD.upsample_boundaries(boundaries, audio_file)

# %% [markdown]
# This function creates a "VAD signal" with the **same dimensionality** as the original audio recording. This way, one can plot them jointly:

# %%
time = torch.linspace(0, signal.shape[0]/fs, steps=signal.shape[0])
plt.plot(time, signal)
plt.plot(time, upsampled_boundaries.squeeze())

# %% [markdown]
# For more details, one can also upsample and visualize VAD scores:

# %%
upsampled_vad_scores = VAD.upsample_VAD(prob_chunks, audio_file)

plt.plot(time, signal)
plt.plot(time, upsampled_boundaries.squeeze())
plt.plot(time, upsampled_vad_scores.squeeze())

# %% [markdown]
# As an alternative, users can save the VAD file and open it with the original one using an audio visualization software like audacity.
#
#
# **That's all! Happy VAD!**

# %% [markdown]
# ---
#
# ## Appendix: on using energy-based VAD
#
# If energy-based VAD is used, the order of the merge, remove, double-check operations matters. Let's use `double_check_speech_segments` right away after energy-based VAD and then `merge_close_segments`. Some speech frames are dropped:

# %%
# plotted boundaries may be scaled down to compare many at once
def plot_boundaries(b, color):
  upsampled = VAD.upsample_boundaries(b, audio_file)
  plt.plot(time, upsampled.squeeze(), color)


# first figures - from CRDNN VAD to energy VAD
fig, axs = plt.subplots(3, 3, figsize=(16, 12))
plt.sca(axs[0, 0])
plt.title('1a. CRDNN VAD scores')
plt.plot(time, signal)

plt.plot(time, upsampled_vad_scores.squeeze(), 'green')

# CRDNN boundaries
plt.sca(axs[1, 0])
plt.title('1b. CRDNN VAD boundaries')
plt.plot(time, signal)

boundaries = VAD.get_boundaries(prob_th)
plot_boundaries(boundaries, 'orange')

# energy VAD boundaries
plt.sca(axs[2, 0])
plt.title('1c. Energy VAD boundaries based on CRDNN')
plt.plot(time, signal)

boundaries_energy = VAD.energy_VAD(audio_file, boundaries, activation_th=0.8, deactivation_th=0.0)
plot_boundaries(boundaries_energy, 'purple')

# second figure - double-check, then merge
plt.sca(axs[0, 1])
plt.title('2a. Energy VAD (same as 1c)')
plt.plot(time, signal)

plot_boundaries(boundaries_energy, 'purple')

# double-check
plt.sca(axs[1, 1])
plt.title('2b. Double-check (too early)')
plt.plot(time, signal)

boundaries = VAD.double_check_speech_segments(boundaries_energy, audio_file,  speech_th=0.5)
plot_boundaries(boundaries, 'red')

# merge (too late)
plt.sca(axs[2, 1])
plt.title('2c. Merge short segments (too late)')
plt.plot(time, signal)

boundaries = VAD.merge_close_segments(boundaries, close_th=0.250)
plot_boundaries(boundaries, 'black')

# third figure - merge, remove, double-check
plt.sca(axs[0, 2])
plt.title('3a. Energy VAD (same as 1c)')
plt.plot(time, signal)

plot_boundaries(boundaries_energy, 'purple')

# merge
plt.sca(axs[1, 2])
plt.title('3b. Merge short segments (as above)')
plt.plot(time, signal)

boundaries = VAD.merge_close_segments(boundaries_energy, close_th=0.250)
plot_boundaries(boundaries, 'black')

# merge
plt.sca(axs[2, 2])
plt.title('3c. Remove short segments & double-check (as above)')
plt.plot(time, signal)

boundaries = VAD.remove_short_segments(boundaries, len_th=0.250)
boundaries = VAD.double_check_speech_segments(boundaries, audio_file,  speech_th=0.5)
plot_boundaries(boundaries, 'red')
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[21], line 43
#      40 plt.title('2b. Double-check (too early)')
#      41 plt.plot(time, signal)
# ---> 43 boundaries = VAD.double_check_speech_segments(boundaries_energy, audio_file,  speech_th=0.5)
#      44 plot_boundaries(boundaries, 'red')
#      46 # merge (too late)
#
# File ~/Documents/NEU/6140_machine_learning/src/.venv/lib/python3.10/site-packages/speechbrain/inference/VAD.py:776, in VAD.double_check_speech_segments(self, boundaries, audio_file, speech_th)
#     772 # Read the candidate speech segment
#     773 segment, fs = audio_io.load(
#     774     str(audio_file), frame_offset=beg_sample, num_frames=len_seg
#     775 )
# --> 776 speech_prob = self.get_speech_prob_chunk(segment)
#     777 if speech_prob.mean() > speech_th:
#     778     # Accept this as a speech segment
#     779     new_boundaries.append([boundaries[i, 0], boundaries[i, 1]])
#
# File ~/Documents/NEU/6140_machine_learning/src/.venv/lib/python3.10/site-packages/speechbrain/inference/VAD.py:257, in VAD.get_speech_prob_chunk(self, wavs, wav_lens)
#     255 feats = self.mods.compute_features(wavs)
#     256 feats = self.mods.mean_var_norm(feats, wav_lens)
# --> 257 outputs = self.mods.cnn(feats)
#     259 outputs = outputs.reshape(
#     260     outputs.shape[0],
#     261     outputs.shape[1],
#     262     outputs.shape[2] * outputs.shape[3],
#     263 )
#     265 outputs, h = self.mods.rnn(outputs)
#
# File ~/Documents/NEU/6140_machine_learning/src/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1776, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1774     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775 else:
# -> 1776     return self._call_impl(*args, **kwargs)
#
# File ~/Documents/NEU/6140_machine_learning/src/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1787, in Module._call_impl(self, *args, **kwargs)
#    1782 # If we don't have any hooks, we want to skip the rest of the logic in
#    1783 # this function, and just call forward.
#    1784 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1785         or _global_backward_pre_hooks or _global_backward_hooks
#    1786         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787     return forward_call(*args, **kwargs)
#    1789 result = None
#    1790 called_always_called_hooks = set()
#
# File ~/Documents/NEU/6140_machine_learning/src/.venv/lib/python3.10/site-packages/speechbrain/nnet/containers.py:158, in Sequential.forward(self, x)
#     145 """Applies layers in sequence, passing only the first element of tuples.
#     146
#     147 Arguments
#    (...)
#     155     Output after all layers are applied.
#     156 """
#     157 for layer in self.values():
# --> 158     x = layer(x)
#     159     if isinstance(x, tuple):
#     160         x = x[0]
#
# File ~/Documents/NEU/6140_machine_learning/src/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1776, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1774     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775 else:
# -> 1776     return self._call_impl(*args, **kwargs)
#
# File ~/Documents/NEU/6140_machine_learning/src/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1787, in Module._call_impl(self, *args, **kwargs)
#    1782 # If we don't have any hooks, we want to skip the rest of the logic in
#    1783 # this function, and just call forward.
#    1784 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1785         or _global_backward_pre_hooks or _global_backward_hooks
#    1786         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787     return forward_call(*args, **kwargs)
#    1789 result = None
#    1790 called_always_called_hooks = set()
#
# File ~/Documents/NEU/6140_machine_learning/src/.venv/lib/python3.10/site-packages/speechbrain/nnet/containers.py:158, in Sequential.forward(self, x)
#     145 """Applies layers in sequence, passing only the first element of tuples.
#     146
#     147 Arguments
#    (...)
#     155     Output after all layers are applied.
#     156 """
#     157 for layer in self.values():
# --> 158     x = layer(x)
#     159     if isinstance(x, tuple):
#     160         x = x[0]
#
# File ~/Documents/NEU/6140_machine_learning/src/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1776, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1774     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775 else:
# -> 1776     return self._call_impl(*args, **kwargs)
#
# File ~/Documents/NEU/6140_machine_learning/src/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1787, in Module._call_impl(self, *args, **kwargs)
#    1782 # If we don't have any hooks, we want to skip the rest of the logic in
#    1783 # this function, and just call forward.
#    1784 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1785         or _global_backward_pre_hooks or _global_backward_hooks
#    1786         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787     return forward_call(*args, **kwargs)
#    1789 result = None
#    1790 called_always_called_hooks = set()
#
# File ~/Documents/NEU/6140_machine_learning/src/.venv/lib/python3.10/site-packages/speechbrain/nnet/CNN.py:676, in Conv2d.forward(self, x)
#     673     x = x.unsqueeze(1)
#     675 if self.padding == "same":
# --> 676     x = self._manage_padding(
#     677         x, self.kernel_size, self.dilation, self.stride
#     678     )
#     680 elif self.padding == "causal":
#     681     num_pad = (self.kernel_size[0] - 1) * self.dilation[1]
#
# File ~/Documents/NEU/6140_machine_learning/src/.venv/lib/python3.10/site-packages/speechbrain/nnet/CNN.py:749, in Conv2d._manage_padding(self, x, kernel_size, dilation, stride)
#     746 padding = padding_time + padding_freq
#     748 # Applying padding
# --> 749 x = nn.functional.pad(x, padding, mode=self.padding_mode)
#     751 return x
#
# File ~/Documents/NEU/6140_machine_learning/src/.venv/lib/python3.10/site-packages/torch/nn/functional.py:5418, in pad(input, pad, mode, value)
#    5411         if mode == "replicate":
#    5412             # Use slow decomp whose backward will be in terms of index_put.
#    5413             # importlib is required because the import cannot be top level
#    5414             # (cycle) and cannot be nested (TS doesn't support)
#    5415             return importlib.import_module(
#    5416                 "torch._decomp.decompositions"
#    5417             )._replication_pad(input, pad)
# -> 5418 return torch._C._nn.pad(input, pad, mode, value)
#
# RuntimeError: Argument #4: Padding size should be less than the corresponding input dimension, but got: padding (1, 1) at dimension 3 of input [1, 1, 40, 1]

# %% [markdown]
# ## Citing SpeechBrain
#
# If you use SpeechBrain in your research or business, please cite it using the following BibTeX entry:
#
# ```bibtex
# @misc{speechbrainV1,
#   title={Open-Source Conversational AI with {SpeechBrain} 1.0},
#   author={Mirco Ravanelli and Titouan Parcollet and Adel Moumen and Sylvain de Langen and Cem Subakan and Peter Plantinga and Yingzhi Wang and Pooneh Mousavi and Luca Della Libera and Artem Ploujnikov and Francesco Paissan and Davide Borra and Salah Zaiem and Zeyu Zhao and Shucong Zhang and Georgios Karakasidis and Sung-Lin Yeh and Pierre Champion and Aku Rouhe and Rudolf Braun and Florian Mai and Juan Zuluaga-Gomez and Seyed Mahed Mousavi and Andreas Nautsch and Xuechen Liu and Sangeet Sagar and Jarod Duret and Salima Mdhaffar and Gaelle Laperriere and Mickael Rouvier and Renato De Mori and Yannick Esteve},
#   year={2024},
#   eprint={2407.00463},
#   archivePrefix={arXiv},
#   primaryClass={cs.LG},
#   url={https://arxiv.org/abs/2407.00463},
# }
# @misc{speechbrain,
#   title={{SpeechBrain}: A General-Purpose Speech Toolkit},
#   author={Mirco Ravanelli and Titouan Parcollet and Peter Plantinga and Aku Rouhe and Samuele Cornell and Loren Lugosch and Cem Subakan and Nauman Dawalatabad and Abdelwahab Heba and Jianyuan Zhong and Ju-Chieh Chou and Sung-Lin Yeh and Szu-Wei Fu and Chien-Feng Liao and Elena Rastorgueva and François Grondin and William Aris and Hwidong Na and Yan Gao and Renato De Mori and Yoshua Bengio},
#   year={2021},
#   eprint={2106.04624},
#   archivePrefix={arXiv},
#   primaryClass={eess.AS},
#   note={arXiv:2106.04624}
# }
# ```
